# %% [markdown]
# ** Medidads de Disperção e Amplitude Total:**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Recapitulando:

amostra=np.array([2500,3200,2700,3000,3400,3700,4500,4700,5000,5200,6000,7000])
media=np.mean(amostra)
mediana=np.median(amostra) 
distancia=(media-mediana)/mediana*100
q1=np.percentile(amostra,25) # o primeiro quartil representa 25% do total da amostra
q2=np.percentile(amostra,50) # 
q3=np.percentile(amostra,75)
iqr=q3-q1  
limite_superior=q3+(1.5*iqr)
limite_inferior=q1-(1.5*iqr)

#Resumo Estatístico
print(f'Média:{media}')
print(f'Mediana:{mediana}')
print(f'Distância entre média e mediana:{distancia:.2f}%')
print(f"Primeiro Quartil (Q1):{q1}")
print(f"Segundo Quartil (Q2):{q2}")
print(f"Terceiro Quartil (Q3):{q3}")
print(f"Intervalo InterQuartil:{iqr}")
print(f"Limite Superior:{limite_superior}")
print(f"Limite Inferior:{limite_inferior}")
# Out:
# Média:4241.666666666667
# Mediana:4100.0
# Distância entre média e mediana:3.46%
# Primeiro Quartil (Q1):3150.0
# Segundo Quartil (Q2):4100.0
# Terceiro Quartil (Q3):5050.0
# Intervalo InterQuartil:1900.0
# Limite Superior:7900.0
# Limite Inferior:300.0

# %%
amostra_df=pd.DataFrame(amostra,columns=['valores'])
print(amostra_df)
# Out:
#     valores
# 0      2500
# 1      3200
# 2      2700
# 3      3000
# 4      3400
# 5      3700
# 6      4500
# 7      4700
# 8      5000
# 9      5200
# 10     6000
# 11     7000

# %%
#Medidas de Dispersão
valor_maximo=amostra_df['valores'].max()
valor_minimo=amostra_df['valores'].min()
amplitude_total=valor_maximo-valor_minimo

print(f'Menor Valor:{valor_minimo}')
print(f'Maior Valor:{valor_maximo}')
print(f'Amplitude:{amplitude_total}')
# Out:
# Menor Valor:2500
# Maior Valor:7000
# Amplitude:4500

# %% [markdown]
# ** Visualização do BoxPlot e Medidas:**

# %%
import matplotlib.pyplot as plt

# Configuração do painel
fig, ax = plt.subplots(1, 2, figsize=(12, 6))   ### chama variáveis de figura e eixos ai chama subplots

# Boxplot
ax[0].boxplot(amostra_df['valores'])
ax[0].set_title('Distribuição de dados - Boxplot')
ax[0].set_ylabel('Valores')

# Exibindo as Medidas
valor_minimo = min(amostra_df['valores'])
valor_maximo = max(amostra_df['valores'])
amplitude_total = valor_maximo - valor_minimo

ax[1].text(0.1, 0.8, f'Menor Valor: {valor_minimo}')
ax[1].text(0.1, 0.7, f'Maior Valor: {valor_maximo}')
ax[1].text(0.1, 0.6, f'Amplitude Total: {amplitude_total}')
ax[1].set_axis_off()

plt.tight_layout() ### ajusta automaticamente os elementos do layout
plt.show() ##  o comando que realmente exibe o gráfico ou gráficos que você criou

# %%
## Atividade 1 :
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

amostra = np.random.randint(0, 10000, size=50)

amostra_df=pd.DataFrame(amostra,columns=['valores'])
display(amostra_df)

# Configuração do painel
fig, ax = plt.subplots(1, 2, figsize=(7,3))   ### chama variáveis de figura e eixos ai chama subplots

# Boxplot
ax[0].boxplot(amostra_df['valores'])
ax[0].set_title('Distribuição de dados - Boxplot')
ax[0].set_ylabel('Valores')

# Exibindo as Medidas
valor_minimo = min(amostra_df['valores'])
valor_maximo = max(amostra_df['valores'])
amplitude_total = valor_maximo - valor_minimo

ax[1].text(0.1, 0.8, f'Menor Valor: {valor_minimo}')
ax[1].text(0.1, 0.7, f'Maior Valor: {valor_maximo}')
ax[1].text(0.1, 0.6, f'Amplitude Total: {amplitude_total}')
ax[1].set_axis_off()

plt.tight_layout() ### ajusta automaticamente os elementos do layout
plt.show() ##  o comando que realmente exibe o gráfico ou gráficos que você criou
# Out:
#     valores
# 0      3100
# 1      9244
# 2      8257
# 3      3277
# 4      3887
# 5      7267
# 6      3821
# 7      9683
# 8      2699
# 9      2576
# 10     9321
# 11     3772
# 12     8558
# 13     8428
# 14     2811
# 15     6769
# 16       50
# 17     6230
# 18     1067
# 19      851
# 20     6914
# 21     9074
# 22     5390
# 23      265
# 24     8878
# 25     4038
# 26     3526
# 27     6972
# 28     3123
# 29     2659
# 30     6816
# 31     6510
# 32     2117
# 33      822
# 34     1899
# 35     8121
# 36     6678
# 37     7991
# 38     6653
# 39     4176
# 40     6176
# 41     8778
# 42     1255
# 43     6481
# 44     6736
# 45      391
# 46       79
# 47     8482
# 48     1132
# 49      377
