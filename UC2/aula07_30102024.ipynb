# %% [markdown]
# ** Quartis em Código:**

# %%
import pandas as pd
import numpy as np 
import random

# %%
amostra=[random.randint(1,99) for i in range(20)]
dados=np.array(amostra)
print(dados) #
# Out:
# [64 60 37 63 76 22 65 89 57 51 49 19 92 99 67 54 36  6 62 17]

# %%
#Cálculo dos Quartis:

q1=np.percentile(dados,25) # o primeiro quartil representa 25% do total da amostra
q2=np.percentile(dados,50) # 
q3=np.percentile(dados,75) # o terceiro quartil representa 75% do total da amostra
#Exibição:

print(f"Primeiro Quartil (Q1):{q1}")
print(f"Segundo Quartil (Q2): {q2}")
print(f"Primeiro Quartil (Q3):{q3}")
# Out:
# Primeiro Quartil (Q1):36.75
# Segundo Quartil (Q2): 58.5
# Primeiro Quartil (Q3):65.5

# %% [markdown]
# ATIVIDADE EM AULA: Calcule os quartis do dataset nutricional trabalho na aula anteror exibindo-os em seguida.

# %%
#ATIVIDADE 2 INICIO

q1=np.percentile(dados,25) # o primeiro quartil representa 25% do total da amostra
q2=np.percentile(dados,50) # 
q3=np.percentile(dados,75) # o terceiro quartil representa 75% do total da amostra

#Exibição:

print(f"Primeiro Quartil (Q1):{q1}")
print(f"Segundo Quartil (Q2): {q2}")
print(f"Primeiro Quartil (Q3):{q3}")
# Out:
# Primeiro Quartil (Q1):36.75
# Segundo Quartil (Q2): 58.5
# Primeiro Quartil (Q3):65.5

# %% [markdown]
# Gráficos - Biblioteca MAtPlotLib

# %%
#lembre-se no terminal, rodar 'pip install matplotlib'
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))   ### delimita área de desenho
plt.bar(range(1,21),dados, color='purple') ## TIPO DE BARRAS ## ESTA TRABALHANDO COM 20 VALORES ##
plt.xlabel('Índices')
plt.ylabel('Valores Aleatórios')
plt.title('Gráfico de Barras dos 20 Números Aleatórios')
plt.xticks(range(1,21)) ## Define os marcadores
plt.show()  #### como se fosse o print
